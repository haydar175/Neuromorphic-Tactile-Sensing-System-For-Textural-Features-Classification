# %% [markdown]
# <a href="https://colab.research.google.com/github/haydar175/Neuromorphic-Tactile-Sensing-System-For-Textural-Features-Classification/blob/main/Plot_SRS_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Delete the old folder
# %cd "/content"
# !rm -r SRS_dataset_88_days
# Out:
# /content
# rm: cannot remove 'SRS_dataset_88_days': No such file or directory

# %%
# Clone the new one
# !git clone https://github.com/cosmiclabunige/SRS_dataset_88_days.git
# Out:
# Cloning into 'SRS_dataset_88_days'...
# remote: Enumerating objects: 481, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 481 (delta 25), reused 11 (delta 3), pack-reused 396
# Receiving objects: 100% (481/481), 5.02 MiB | 13.55 MiB/s, done.
# Resolving deltas: 100% (160/160), done.

# %%
# Install the missing packages if needed
# !pip install enlighten
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# Change directory to the folder
# %cd "/content/SRS_dataset_88_days/Wet_Dry_Classification"
# Out:
# /content/SRS_dataset_88_days/Wet_Dry_Classification

# %%
# Open the Main.py file to implement some modifications if needed
# %run /content/SRS_dataset_88_days/Wet_Dry_Classification/Python/Main.py
# Out:
# MODEL ADA Specificity No Rain: percentage below lower wisk 13.33, percentage above higher wisk 0.00
# MODEL ANN Specificity No Rain: percentage below lower wisk 8.89, percentage above higher wisk 0.00
# MODEL CNN Specificity No Rain: percentage below lower wisk 6.67, percentage above higher wisk 0.00
# MODEL ADA Specificity Rain: percentage below lower wisk 9.09, percentage above higher wisk 0.00
# MODEL ADA Recall Rain: percentage below lower wisk 0.00, percentage above higher wisk 0.00
# MODEL ADA HM Rain: percentage below lower wisk 0.00, percentage above higher wisk 0.00
# MODEL ANN Specificity Rain: percentage below lower wisk 6.06, percentage above higher wisk 0.00
# MODEL ANN Recall Rain: percentage below lower wisk 9.09, percentage above higher wisk 0.00
# MODEL ANN HM Rain: percentage below lower wisk 6.06, percentage above higher wisk 0.00
# MODEL CNN Specificity Rain: percentage below lower wisk 6.06, percentage above higher wisk 0.00
# ...
